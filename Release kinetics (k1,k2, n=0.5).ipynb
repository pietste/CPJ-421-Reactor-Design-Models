# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
from lmfit import Minimizer, Parameters, report_fit
# %matplotlib notebook

# %%
M = np.matrix(pandas.read_excel('Dataminus.xlsx'))
time = M[:,0]/60
lim1 = M[:,1]
def rate_release(k1, k2):
    M_t = k1*t**0.5 + k2*t
    return M_t

t = np.linspace(0,1000,10000)
Z = (time,lim1)
def func(params, Z):
    Z = time,lim1
    k1 = params['k1']
    k2 = params['k2']
    def rate_release(k1, k2):
        M_t = k1*t**0.5 + k2*t
        return M_t
    M_t = rate_release(k1,k2)
    Mlim1 = np.interp(time,t,M_t)
    ERROR = abs(lim1 - Mlim1)
    return ERROR
def Model1(k1,k2,Z):
    Z = time,lim1
    def rate_release(k1, k2):
        M_t = k1*t**0.5 + k2*t
        return M_t
    M_t = rate_release(k1,k2)
    plt.figure('d-limonene sample 1')
    plt.plot(time,lim1, marker='o', color='darkgreen', linestyle='', label='Experimental data')
    plt.plot(t, M_t, color='darkgreen', label='Fitted model')
    plt.xlabel('Time (h)')
    plt.ylabel('Mass fraction released')
    plt.axis([0,100,0,1])
    plt.legend(loc='best')
    plt.show()
    plt.figure('Compare')
    plt.plot(time,lim1, marker='o',markeredgecolor='none', color='green', linestyle='', label='Sample 1 data')
    plt.plot(t, M_t, color='green', label='Model 2.1')
    plt.xlabel('Time (h)')
    plt.ylabel('Mass fraction released ($M(t)/M_\infty$)')
    plt.axis([0,100,0,1])
    plt.legend(loc='best')
    plt.show()

params = Parameters()
params.add('k1',   value= 0.00001,  min=0, max= 5)
params.add('k2',   value= 0.00001,  min=0, max=5)
minner = Minimizer(func, params,fcn_args=(Z,))
result1 = minner.minimize()
k1 = result1.params['k1']
k2 = result1.params['k2']
print(report_fit(result1))
Model1(k1,k2,Z)
# Out:
# [[Fit Statistics]]
#     # function evals   = 39
#     # data points      = 12
#     # variables        = 2
#     chi-square         = 0.012
#     reduced chi-square = 0.001
#     Akaike info crit   = -78.480
#     Bayesian info crit = -77.511
# [[Variables]]
#     k1:   0.08424866 +/- 0.008432 (10.01%) (init= 1e-05)
#     k2:   0.00178816 +/- 0.001081 (60.50%) (init= 1e-05)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(k1, k2)                    = -0.971
# None
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
lim1 = M[:,2]
def rate_release(k1, k2):
    M_t = k1*t**0.5 + k2*t
    return M_t

t = np.linspace(0,1000,10000)
Z = (time,lim1)
def func(params, Z):
    Z = time,lim1
    k1 = params['k1']
    k2 = params['k2']
    def rate_release(k1, k2):
        M_t = k1*t**0.5 + k2*t
        return M_t
    M_t = rate_release(k1,k2)
    Mlim1 = np.interp(time,t,M_t)
    ERROR = abs(lim1 - Mlim1)
    return ERROR
def Model1(k1,k2,Z):
    Z = time,lim1
    def rate_release(k1, k2):
        M_t = k1*t**0.5 + k2*t
        return M_t
    M_t = rate_release(k1,k2)
    plt.figure('d-limonene sample 2')
    plt.plot(time,lim1, marker='o', color='green', linestyle='', label='Experimental data')
    plt.plot(t, M_t, color='green', label='Fitted model')
    plt.xlabel('Time (h)')
    plt.ylabel('Mass fraction released')
    plt.axis([0,100,0,1])
    plt.legend(loc='best')
    plt.show()
    plt.figure('Compare')
    plt.plot(time,lim1,marker='^',   markerfacecolor='none', markeredgecolor='darkgreen', linestyle='', label='Sample 2 data')
    plt.plot(t, M_t, color='darkgreen',linestyle='--', label='Model 2.2')
    plt.xlabel('Time (h)')
    plt.ylabel('Mass fraction released ($M(t)/M_\infty$)')
    plt.axis([0,100,0,1])
    plt.legend(loc='best')
    plt.show()

params = Parameters()
params.add('k1',   value= 0.00001,  min=0, max= 5)
params.add('k2',   value= 0.00001,  min=0, max=5)
minner = Minimizer(func, params,fcn_args=(Z,))
result2 = minner.minimize()
k1 = result2.params['k1']
k2 = result2.params['k2']
print(report_fit(result2))
Model1(k1,k2,Z)
# Out:
# [[Fit Statistics]]
#     # function evals   = 42
#     # data points      = 12
#     # variables        = 2
#     chi-square         = 0.011
#     reduced chi-square = 0.001
#     Akaike info crit   = -79.491
#     Bayesian info crit = -78.521
# [[Variables]]
#     k1:   0.10056869 +/- 0.008084 (8.04%) (init= 1e-05)
#     k2:   0.00028919 +/- 0.001037 (358.64%) (init= 1e-05)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(k1, k2)                    = -0.971
# None
# <img src="data:image/png;base64,...">

# %%
lim1 = M[:,3]
def rate_release(k1, k2):
    M_t = k1*t**0.5 + k2*t
    return M_t

t = np.linspace(0,1000,10000)
Z = (time,lim1)
def func(params, Z):
    Z = time,lim1
    k1 = params['k1']
    k2 = params['k2']
    def rate_release(k1, k2):
        M_t = k1*t**0.5 + k2*t
        return M_t
    M_t = rate_release(k1,k2)
    Mlim1 = np.interp(time,t,M_t)
    ERROR = abs(lim1 - Mlim1)
    return ERROR
def Model1(k1,k2,Z):
    Z = time,lim1
    def rate_release(k1, k2):
        M_t = k1*t**0.5 + k2*t
        return M_t
    M_t = rate_release(k1,k2)
    plt.figure('citronellal sample 3')
    plt.plot(time,lim1, marker='o', color='darkorange', linestyle='', label='Experimental data')
    plt.plot(t, M_t, color='darkorange', label='Fitted model')
    plt.xlabel('Time (h)')
    plt.ylabel('Mass fraction released')
    plt.axis([0,100,0,1])
    plt.legend(loc='best')
    plt.show()
    plt.figure('Compare1')
    plt.plot(time,lim1, marker='o',markeredgecolor='none', color='orange', linestyle='', label='Sample 3 data')
    plt.plot(t, M_t, color='orange', label='Model 2.3')
    plt.xlabel('Time (h)')
    plt.ylabel('Mass fraction released ($M(t)/M_\infty$)')
    plt.axis([0,100,0,1])
    plt.legend(loc='best')
    plt.show()

params = Parameters()
params.add('k1',   value= 0.00001,  min=0, max= 5)
params.add('k2',   value= 0.00001,  min=0, max=5)
minner = Minimizer(func, params,fcn_args=(Z,))
result3 = minner.minimize()
k1 = result3.params['k1']
k2 = result3.params['k2']
print(report_fit(result3))
Model1(k1,k2,Z)
# Out:
# [[Fit Statistics]]
#     # function evals   = 35
#     # data points      = 12
#     # variables        = 2
#     chi-square         = 0.022
#     reduced chi-square = 0.002
#     Akaike info crit   = -71.814
#     Bayesian info crit = -70.844
# [[Variables]]
#     k1:   0.07290104 +/- 0.011131 (15.27%) (init= 1e-05)
#     k2:   0.00323804 +/- 0.001428 (44.11%) (init= 1e-05)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(k1, k2)                    = -0.971
# None
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
lim1 = M[:,4]
def rate_release(k1, k2):
    M_t = k1*t**0.5 + k2*t
    return M_t

t = np.linspace(0,1000,10000)
Z = (time,lim1)
def func(params, Z):
    Z = time,lim1
    k1 = params['k1']
    k2 = params['k2']
    def rate_release(k1, k2):
        M_t = k1*t**0.5 + k2*t
        return M_t
    M_t = rate_release(k1,k2)
    Mlim1 = np.interp(time,t,M_t)
    ERROR = abs(lim1 - Mlim1)
    return ERROR
def Model1(k1,k2,Z):
    Z = time,lim1
    def rate_release(k1, k2):
        M_t = k1*t**0.5 + k2*t
        return M_t
    M_t = rate_release(k1,k2)
    plt.figure('citronellal sample 4')
    plt.plot(time,lim1, marker='o', color='orange', linestyle='', label='Experimental data')
    plt.plot(t, M_t, color='orange', label='Fitted model')
    plt.xlabel('Time (h)')
    plt.ylabel('Mass fraction released')
    plt.axis([0,100,0,1])
    plt.legend(loc='best')
    plt.show()
    plt.figure('Compare1')
    plt.plot(time,lim1, marker='^',markerfacecolor='none',markeredgecolor='darkorange', color='darkorange', linestyle='', label='Sample 4 data')
    plt.plot(t, M_t, color='darkorange',linestyle='--', label='Model 2.4')
    plt.xlabel('Time (h)')
    plt.ylabel('Mass fraction released ($M(t)/M_\infty$)')
    plt.axis([0,100,0,1])
    plt.legend(loc='best')
    plt.show()

params = Parameters()
params.add('k1',   value= 0.00001,  min=0, max= 5)
params.add('k2',   value= 0.00001,  min=0, max=5)
minner = Minimizer(func, params,fcn_args=(Z,))
result4 = minner.minimize()
k1 = result4.params['k1']
k2 = result4.params['k2']
print(report_fit(result4))
Model1(k1,k2,Z)
# Out:
# [[Fit Statistics]]
#     # function evals   = 42
#     # data points      = 12
#     # variables        = 2
#     chi-square         = 0.003
#     reduced chi-square = 0.000
#     Akaike info crit   = -95.897
#     Bayesian info crit = -94.927
# [[Variables]]
#     k1:   0.00975326 +/- 0.004081 (41.84%) (init= 1e-05)
#     k2:   0.00969947 +/- 0.000524 (5.40%) (init= 1e-05)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(k1, k2)                    = -0.971
# None
# <img src="data:image/png;base64,...">

# %%
lim1 = M[:,5]
def rate_release(k1, k2):
    M_t = k1*t**0.5 + k2*t**1
    return M_t

t = np.linspace(0,1000,10000)
Z = (time,lim1)
def func(params, Z):
    Z = time,lim1
    k1 = params['k1']
    k2 = params['k2']
    def rate_release(k1, k2):
        M_t = k1*t**0.5 + k2*t**1
        return M_t
    M_t = rate_release(k1,k2)
    Mlim1 = np.interp(time,t,M_t)
    ERROR = abs(lim1 - Mlim1)
    return ERROR
def Model25(k1,k2,Z):
    Z = time,lim1
    def rate_release(k1, k2):
        M_t = k1*t**0.5+ k2*t**1
        return M_t
    M_t = rate_release(k1,k2)
    plt.figure('IR3535 sample 5')
    plt.plot(time,lim1, marker='o', color='blue', linestyle='', label='Sample 5 data')
    plt.plot(t, M_t, color='blue', label='Model 2.5')
    plt.xlabel('Time (h)')
    plt.ylabel('Mass fraction gained ($M(t)/M_\infty$)')
    plt.axis([0,100,0,1])
    plt.legend(loc='best')
    plt.show()

params = Parameters()
params.add('k1',   value= 0.00001,  min=0, max= 5)
params.add('k2',   value= 0.00001,  min=0, max=5)
minner = Minimizer(func, params,fcn_args=(Z,))
result5 = minner.minimize()
k1 = result5.params['k1']
k2 = result5.params['k2']
print(report_fit(result5))
Model25(k1,k2,Z)
# Out:
# [[Fit Statistics]]
#     # function evals   = 64
#     # data points      = 12
#     # variables        = 2
#     chi-square         = 0.018
#     reduced chi-square = 0.002
#     Akaike info crit   = -74.288
#     Bayesian info crit = -73.318
# [[Variables]]
#     k1:   0          +/- 4.00e-06 (inf%) (init= 1e-05)
#     k2:   0.01089145 +/- 0.001288 (11.83%) (init= 1e-05)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(k1, k2)                    = -0.971
# None
# <img src="data:image/png;base64,...">

# %%
t_m = np.array(time)**0.5
F = 1/(1+ (0.00178816 /0.08424866 )*(t_m)**0.5)
R = F*(0.00178816 /0.08424866 )*(t_m)**0.5
plt.figure('1')
plt.plot(time,F, label='F')
plt.plot(time,R, label='R')
plt.xlabel('Time (h)')
plt.ylabel('F/R')
plt.axis([0,100,0,1])
plt.legend(loc='best')
plt.show()
F[-1]
# Out:
# <img src="data:image/png;base64,...">
# array([ 0.93847835])

# %%
F = 1/(1+ (0.00028919 /0.10056869 )*(t_m)**0.5)
R = F*(0.00028919 /0.10056869 )*(t_m)**0.5
plt.figure('2')
plt.plot(time,F, label='F')
plt.plot(time,R, label='R')
plt.xlabel('Time (h)')
plt.ylabel('F/R')
plt.axis([0,100,0,1])
plt.legend(loc='best')
plt.show()
F[-1]
# Out:
# <img src="data:image/png;base64,...">
# array([ 0.9911968])

# %%
F = 1/(1+ (0.00323804/0.07290104)*(t_m)**0.5)
R = F*(0.00323804/0.07290104 )*(t_m)**0.5
plt.figure('3')
plt.plot(time,F, label='F')
plt.plot(time,R, label='R')
plt.xlabel('Time (h)')
plt.ylabel('F/R')
plt.axis([0,100,0,1])
plt.legend(loc='best')
plt.show()
F[-1]
# Out:
# <img src="data:image/png;base64,...">
# array([ 0.87936386])

# %%
F = 1/(1+ (0.00969947/0.00975326)*(t_m)**0.5)
R = F*(0.00969947/0.00975326 )*(t_m)**0.5
plt.figure('4')
plt.plot(time,F, label='F')
plt.plot(time,R, label='R')
plt.xlabel('Time (h)')
plt.ylabel('F/R')
plt.axis([0,100,0,1])
plt.legend(loc='best')
plt.show()
F[-1]
# Out:
# <img src="data:image/png;base64,...">
# array([ 0.2456063])

# %%
F = 1/(1+ (0.01089145/0.000004)*(t_m)**0.5)
R = F*(0.01089145/0.000004 )*(t_m)**0.5
plt.figure('5')
plt.plot(time,F, label='F')
plt.plot(time,R, label='R')
plt.xlabel('Time (h)')
plt.ylabel('F/R')
plt.axis([0,100,-0.1,1.1])
plt.legend(loc='best')
plt.show()
# Out:
# <img src="data:image/png;base64,...">
