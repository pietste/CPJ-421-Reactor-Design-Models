# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
from lmfit import Minimizer, Parameters, report_fit
# %matplotlib notebook

# %%
M = np.matrix(pandas.read_excel('Dataminus.xlsx'))
time = M[:,0]/60
lim1 = M[:,1]
def rate_release(k, n):
    M_t = k*t**n
    return M_t

t = np.linspace(0,1000,10000)
Z = (time,lim1)
def func(params, Z):
    Z = time,lim1
    n = params['n']
    k = params['k']
    def rate_release(k, n):
        M_t = k*t**n
        return M_t
    M_t = rate_release(k,n)
    Mlim1 = np.interp(time,t,M_t)
    ERROR = abs(lim1 - Mlim1)
    return ERROR
def Model1(n,k,Z):
    Z = time,lim1
    def rate_release(k, n):
        M_t = k*t**n
        return M_t
    M_t = rate_release(k,n)
    plt.figure('d-limonene sample 1')
    plt.plot(time,lim1, marker='o', color='darkgreen', linestyle='', label='Experimental data')
    plt.plot(t, M_t, color='darkgreen', label='Fitted model')
    plt.xlabel('Time (h)')
    plt.ylabel('Mass fraction released')
    plt.axis([0,100,0,1])
    plt.legend(loc='best')
    plt.show()
    plt.figure('Compare')
    plt.plot(time,lim1, marker='o', markeredgecolor='none', color='green', linestyle='', label='Sample 1 data')
    plt.plot(t, M_t, color='green', label='Model 1.1')
    plt.xlabel('Time (h)')
    plt.ylabel('Mass fraction released')
    plt.axis([0,100,0,1])
    plt.legend(loc='best')
    plt.show()

params = Parameters()
params.add('n',   value= 0.00001,  min=0, max= 1)
params.add('k',   value= 0.00001,  min=0, max=5)
minner = Minimizer(func, params,fcn_args=(Z,))
result1 = minner.minimize()
n1 = result1.params['n']
k1 = result1.params['k']
print(report_fit(result1))
Model1(n1,k1,Z)
# Out:
# [[Fit Statistics]]
#     # function evals   = 62
#     # data points      = 12
#     # variables        = 2
#     chi-square         = 0.015
#     reduced chi-square = 0.001
#     Akaike info crit   = -76.410
#     Bayesian info crit = -75.440
# [[Variables]]
#     n:   0.52901674 +/- 0.033402 (6.31%) (init= 1e-05)
#     k:   0.08716478 +/- 0.011758 (13.49%) (init= 1e-05)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(n, k)                      = -0.986
# None
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
lim1 = M[:,2]
def rate_release(k, n):
    M_t = (k*t)**n
    return M_t

t = np.linspace(0,1000,10000)
Z = (time,lim1)
def func(params, Z):
    Z = time,lim1
    n = params['n']
    k = params['k']
    def rate_release(k, n):
        M_t = (k*t)**n
        return M_t
    M_t = rate_release(k,n)
    Mlim1 = np.interp(time,t,M_t)
    ERROR = abs(lim1 - Mlim1)
    return ERROR
def Model1(n,k,Z):
    Z = time,lim1
    def rate_release(k, n):
        M_t = (k*t)**n
        return M_t
    M_t = rate_release(k,n)
    plt.figure('d-limonene sample 2')
    plt.plot(time,lim1, marker='o', color='darkgreen', linestyle='', label='Experimental data')
    plt.plot(t, M_t, color='darkgreen', label='Fitted model')
    plt.xlabel('Time (h)')
    plt.ylabel('Mass fraction released')
    plt.axis([0,100,0,1])
    plt.legend(loc='best')
    plt.show()
    plt.figure('Compare')
    plt.plot(time,lim1, marker='^',   markerfacecolor='none', markeredgecolor='darkgreen', linestyle='', label='Sample 2 data')
    plt.plot(t, M_t, color='darkgreen',linestyle='--', label='Model 1.2')
    plt.xlabel('Time (h)')
    plt.ylabel('Mass fraction released ($M(t)/M_\infty$)')
    plt.axis([0,100,0,1])
    plt.legend(loc='best')
    plt.show()
    

params = Parameters()
params.add('n',   value= 0.00001,  min=0, max= 2)
params.add('k',   value= 0.00001,  min=0, max=5)
minner = Minimizer(func, params,fcn_args=(Z,))
result2 = minner.minimize()
n2 = result2.params['n']
k2 = result2.params['k']
print(report_fit(result2))
Model1(n2,k2,Z)
# Out:
# [[Fit Statistics]]
#     # function evals   = 94
#     # data points      = 12
#     # variables        = 2
#     chi-square         = 0.011
#     reduced chi-square = 0.001
#     Akaike info crit   = -79.448
#     Bayesian info crit = -78.478
# [[Variables]]
#     n:   0.49449841 +/- 0.026056 (5.27%) (init= 1e-05)
#     k:   0.01048924 +/- 0.000521 (4.97%) (init= 1e-05)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(n, k)                      =  0.646
# None
# <img src="data:image/png;base64,...">

# %%
lim1 = M[:,3]
def rate_release(k, n):
    M_t = (k*t)**n
    return M_t

t = np.linspace(0,1000,10000)
Z = (time,lim1)
def func(params, Z):
    Z = time,lim1
    n = params['n']
    k = params['k']
    def rate_release(k, n):
        M_t = (k*t)**n
        return M_t
    M_t = rate_release(k,n)
    Mlim1 = np.interp(time,t,M_t)
    ERROR = abs(lim1 - Mlim1)
    return ERROR
def Model1(n,k,Z):
    Z = time,lim1
    def rate_release(k, n):
        M_t = (k*t)**n
        return M_t
    M_t = rate_release(k,n)
    plt.figure('citronellal sample 3')
    plt.plot(time,lim1, marker='o', color='darkorange', linestyle='', label='Experimental data')
    plt.plot(t, M_t, color='darkorange', label='Fitted model ')
    plt.xlabel('Time (h)')
    plt.ylabel('Mass fraction released')
    plt.axis([0,100,0,1])
    plt.legend(loc='best')
    plt.show()
    plt.figure('Compare1')
    plt.plot(time,lim1, marker='o', markeredgecolor='none', color='orange', linestyle='', label='Sample 3 data')
    plt.plot(t, M_t, color='orange', label='Model 1.3')
    plt.xlabel('Time (h)')
    plt.ylabel('Mass fraction released ($M(t)/M_\infty$)')
    plt.axis([0,100,0,1])
    plt.legend(loc='best')
    plt.show()
    

params = Parameters()
params.add('n',   value= 0.00001,  min=0, max= 1)
params.add('k',   value= 0.00001,  min=0, max=5)
minner = Minimizer(func, params,fcn_args=(Z,))
result3 = minner.minimize()
n3 = result3.params['n']
k3 = result3.params['k']
print(report_fit(result3))
Model1(n3,k3,Z)
# Out:
# [[Fit Statistics]]
#     # function evals   = 22
#     # data points      = 12
#     # variables        = 2
#     chi-square         = 0.017
#     reduced chi-square = 0.002
#     Akaike info crit   = -74.880
#     Bayesian info crit = -73.910
# [[Variables]]
#     n:   0.60922069 +/- 0.041502 (6.81%) (init= 1e-05)
#     k:   0.01072003 +/- 0.000552 (5.15%) (init= 1e-05)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(n, k)                      =  0.650
# None
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
lim1 = M[:,4]
def rate_release(k, n):
    M_t = (k*t)**n
    return M_t

t = np.linspace(0,1000,10000)
Z = (time,lim1)
def func(params, Z):
    Z = time,lim1
    n = params['n']
    k = params['k']
    def rate_release(k, n):
        M_t = (k*t)**n
        return M_t
    M_t = rate_release(k,n)
    Mlim1 = np.interp(time,t,M_t)
    ERROR = abs(lim1 - Mlim1)
    return ERROR
def Model1(n,k,Z):
    Z = time,lim1
    def rate_release(k, n):
        M_t = (k*t)**n
        return M_t
    M_t = rate_release(k,n)
    plt.figure('citronellal sample 4')
    plt.plot(time,lim1, marker='o', color='orange', linestyle='', label='Experimental data')
    plt.plot(t, M_t, color='darkorange', label='Fitted model')
    plt.xlabel('Time (h)')
    plt.ylabel('Mass fraction released')
    plt.axis([0,100,0,1])
    plt.legend(loc='best')
    plt.show()
    plt.figure('Compare1')
    plt.plot(time,lim1, marker='^',  markerfacecolor='none', markeredgecolor='darkorange', linestyle='', label='Sample 4 data')
    plt.plot(t, M_t, color='darkorange',linestyle='--', label='Model 1.4')
    plt.xlabel('Time (h)')
    plt.ylabel('Mass fraction released ($M(t)/M_\infty$)')
    plt.axis([0,100,0,1])
    plt.legend(loc='best')
    plt.show()

params = Parameters()
params.add('n',   value= 0.00001,  min=0, max= 1)
params.add('k',   value= 0.00001,  min=0, max=5)
minner = Minimizer(func, params,fcn_args=(Z,))
result4 = minner.minimize()
n4 = result4.params['n']
k4 = result4.params['k']
print(report_fit(result4))
Model1(n4,k4,Z)
# Out:
# [[Fit Statistics]]
#     # function evals   = 120
#     # data points      = 12
#     # variables        = 2
#     chi-square         = 0.004
#     reduced chi-square = 0.000
#     Akaike info crit   = -92.584
#     Bayesian info crit = -91.615
# [[Variables]]
#     n:   0.94930264 +/- 0.034138 (3.60%) (init= 1e-05)
#     k:   0.01073156 +/- 0.000199 (1.85%) (init= 1e-05)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(n, k)                      =  0.668
# None
# <img src="data:image/png;base64,...">

# %%
lim1 = M[:,5]
def rate_release(k, n):
    M_t = (k*t)**n
    return M_t

t = np.linspace(0,1000,10000)
Z = (time,lim1)
def func(params, Z):
    Z = time,lim1
    n = params['n']
    k = params['k']
    def rate_release(k, n):
        M_t = (k*t)**n
        return M_t
    M_t = rate_release(k,n)
    Mlim1 = np.interp(time,t,M_t)
    ERROR = abs(lim1 - Mlim1)
    return ERROR
def Model1(n,k,Z):
    Z = time,lim1
    def rate_release(k, n):
        M_t = (k*t)**n
        return M_t
    M_t = rate_release(k,n)
    plt.figure('IR3535 sample 5')
    plt.plot(time,lim1, marker='o', color='blue', linestyle='', label='Sample 5 data')
    plt.plot(t, M_t, color='blue', label='Model 1.5')
    plt.xlabel('Time (h)')
    plt.ylabel('Mass fraction  gained ($M(t)/M_\infty$)')
    plt.axis([0,100,0,1])
    plt.legend(loc='best')
    plt.show()

params = Parameters()
params.add('n',   value= 0.00001,  min=0, max= 1)
params.add('k',   value= 0.00001,  min=0, max=5)
minner = Minimizer(func, params,fcn_args=(Z,))
result5 = minner.minimize()
n5 = result5.params['n']
k5 = result5.params['k']
print(report_fit(result5))
Model1(n5,k5,Z)
# Out:
# [[Fit Statistics]]
#     # function evals   = 684
#     # data points      = 12
#     # variables        = 2
#     chi-square         = 0.018
#     reduced chi-square = 0.002
#     Akaike info crit   = -74.288
#     Bayesian info crit = -73.318
# [[Variables]]
#     n:   0.99999998 +/- 0.077409 (7.74%) (init= 1e-05)
#     k:   0.01089290 +/- 0.000403 (3.70%) (init= 1e-05)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(n, k)                      = -0.649
# None
# <img src="data:image/png;base64,...">
